# %% [markdown]
# # Opening a new Italian restaurant in London, UK

# %% [markdown]
# By Aria Kumar

# %% [markdown]
# ## Introduction/Business Problem

# %% [markdown]
# London is one of the world's major cities and is a diverse multicultural hub with over 300 languages being spoken here. The city is world famous for its history, culture, attractions, art, shopping opportunities and food. There are around 15,500 restaurants in London according to the Office of National Statistics, making London one of the most ideal places in the world to open a restaurant. London hosts approximately 30 million tourists each year, so the demand for restaurants is always high and business will never be low if opened in the right place.
#
# Londoners favourite cusine is Italian with approximately 30% saying it is their favourite food to eat out for. According to https://www.prnewswire.com/news-releases/food-for-thought-the-average-brit-spends-ps700-on-eating-out-per-year-here-s-how-to-do-it-for-less-with-budget-meal-ideas-in-2019-826776701.html
#
# The objective of this project is to analyse and find the best location to open an Italian food restaurant in London.
#
# The target audience for this project is a businessman who wants to invest in a location in London to open an Italian Restaurant.

# %% [markdown]
# ## Data

# %% [markdown]
# Problem Statement: Where is the best location to open an Italian restaurant in London?
#
# I will be getting data from following sources:
#
# + The Neighbourhoods of London and their postcodes using Wikipedia(https://en.wikipedia.org/wiki/List_of_areas_of_London)
# + The Locations in each Neighbourhood in London area(https://developer.foursquare.com/)
# + Coordinates of each Neighbourhood/postcode using geocoder python library(https://developers.arcgis.com/python/guide/using-the-geocode-function/)
#
# How will I use the data?
#
# 1. Get the Neighbourhoods data from Wikipedia using Beautiful Soup library.
# 2. Explore the venues and their category in each Neighbourhood using Foursquare API.
# 3. Get the latitude and longitude data using Geocoder library.
# 4. Combine the data above into one dataframe.
# 5. Group by Neighbourhood and count the occurrences of Venues for each Neighbourhood.
# 6. Cluster each Neighbourhood based on the venues and add the cluster back into the initial dataframe
# 7. Identify patterns in each cluster and the most common venue.
# 8. Data visualisation will be done using Folium maps
# 9. Will use machine learning clustering techniques to hopefully get an ideal location

# %%
# !pip install geopy
# !pip install geocoder
# !pip install folium
# !pip install beautifulsoup4 
# !pip install lxml 
# !pip install split
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.18.1)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geopy) (1.49)
# Requirement already satisfied: geocoder in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.38.1)
# Requirement already satisfied: click in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (7.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (2.21.0)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: future in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: ratelim in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2019.9.11)
# Requirement already satisfied: decorator in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ratelim->geocoder) (4.3.2)
# Requirement already satisfied: folium in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.10.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (0.3.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2019.9.11)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from beautifulsoup4) (1.7.1)
# Requirement already satisfied: lxml in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.3.1)
# Requirement already satisfied: split in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.4)

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json
from geopy.geocoders import Nominatim

import requests
from pandas.io.json import json_normalize 

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans
import folium

from bs4 import BeautifulSoup
import string

from sklearn import metrics
from scipy.spatial.distance import cdist
import numpy as np
import matplotlib as plt
from matplotlib import pyplot

# %%
import requests 
import pandas as pd 
import numpy as np 
import random 

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 

from IPython.display import Image 
from IPython.core.display import HTML 
    
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium 

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.10.16-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.9.11-py36_0              --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     altair-3.3.0               |           py36_0         747 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         846 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.3.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# altair-3.3.0         | 747 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
list1 = pd.read_html("https://en.wikipedia.org/wiki/List_of_areas_of_London",header=0)
type(list1)
# Out:
# list

# %%
df = list1[1]
df.head()
# Out:
#       Location                     London borough       Post town  \
# 0   Abbey Wood              Bexley, Greenwich [7]          LONDON
# 1        Acton  Ealing, Hammersmith and Fulham[8]          LONDON
# 2    Addington                         Croydon[8]         CROYDON
# 3   Addiscombe                         Croydon[8]         CROYDON
# 4  Albany Park                             Bexley  BEXLEY, SIDCUP
#
#   Postcode district Dial code OS grid ref
# 0               SE2       020    TQ465785
# 1            W3, W4       020    TQ205805
# 2               CR0       020    TQ375645
# 3               CR0       020    TQ345665
# 4         DA5, DA14       020    TQ478728

# %%
print(df.columns)

df.rename(columns={"Location":"Neighourhood"}, inplace=True)
df.head()
# Out:
# Index(['Location', 'London borough', 'Post town', 'Postcode district',
#        'Dial code', 'OS grid ref'],
#       dtype='object')
#   Neighourhood                     London borough       Post town  \
# 0   Abbey Wood              Bexley, Greenwich [7]          LONDON
# 1        Acton  Ealing, Hammersmith and Fulham[8]          LONDON
# 2    Addington                         Croydon[8]         CROYDON
# 3   Addiscombe                         Croydon[8]         CROYDON
# 4  Albany Park                             Bexley  BEXLEY, SIDCUP
#
#   Postcode district Dial code OS grid ref
# 0               SE2       020    TQ465785
# 1            W3, W4       020    TQ205805
# 2               CR0       020    TQ375645
# 3               CR0       020    TQ345665
# 4         DA5, DA14       020    TQ478728

# %%
print(df.columns)
# Out:
# Index(['Neighourhood', 'London borough', 'Post town', 'Postcode district',
#        'Dial code', 'OS grid ref'],
#       dtype='object')

# %%
for index,value in enumerate(df['Borough']):
    
    df.at[index,'Borough']=value.split('[')[0]
df['Borough'] =  df['Borough'].apply(lambda x: x.split(",")[0])

df['Postcode'] =  df['Postcode'].apply(lambda x: x.split(",")[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Borough'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-f15bcbdf35d3> in <module>
# ----> 1 for index,value in enumerate(df['Borough']):
#       2
#       3     df.at[index,'Borough']=value.split('[')[0]
#       4 df['Borough'] =  df['Borough'].apply(lambda x: x.split(",")[0])
#       5
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Borough'

# %%
df.head()
# Out:
#   Neighourhood                     London borough       Post town  \
# 0   Abbey Wood              Bexley, Greenwich [7]          LONDON
# 1        Acton  Ealing, Hammersmith and Fulham[8]          LONDON
# 2    Addington                         Croydon[8]         CROYDON
# 3   Addiscombe                         Croydon[8]         CROYDON
# 4  Albany Park                             Bexley  BEXLEY, SIDCUP
#
#   Postcode district Dial code OS grid ref
# 0               SE2       020    TQ465785
# 1            W3, W4       020    TQ205805
# 2               CR0       020    TQ375645
# 3               CR0       020    TQ345665
# 4         DA5, DA14       020    TQ478728

# %%
df.dtypes
# Out:
# Neighourhood         object
# London borough       object
# Post town            object
# Postcode district    object
# Dial code            object
# OS grid ref          object
# dtype: object

# %%
df = df.astype(str)
df.dtypes
# Out:
# Neighourhood         object
# London borough       object
# Post town            object
# Postcode district    object
# Dial code            object
# OS grid ref          object
# dtype: object

# %%
df.sort_values(by='Postcode',ascending=True,inplace=True)
df.reset_index(drop=True,inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-139-8cc5e0fd871a> in <module>
# ----> 1 df.sort_values(by='Postcode',ascending=True,inplace=True)
#       2 df.reset_index(drop=True,inplace=True)
#       3 df.head()
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1705             values = self.axes[axis].get_level_values(key)._values
#    1706         else:
# -> 1707             raise KeyError(key)
#    1708
#    1709         # Check for duplicates
#
# KeyError: 'Postcode'

# %%
df.shape
# Out:
# (533, 6)

# %%
import geopy
address="London,UK"
geolocator = Nominatim(user_agent="London_explorer")
lat_lng_coords = None

while(lat_lng_coords is None):
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    lat_lng_coords=[latitude,longitude]

print('The geograpical coordinate of London are {}, {}.'.format(lat_lng_coords[0], lat_lng_coords[1]))
# Out:
# The geograpical coordinate of London are 51.5073219, -0.1276474.

# %%
import geocoder
Latitude_list=[]
Longitude_list=[]
for i in range(df.shape[0]):
    address='{}, London,UK'.format(df.at[i,'Postcode'])   
    g = geocoder.arcgis(address)
    Latitude_list.append(g.latlng[0])
    Longitude_list.append(g.latlng[1])

# %%
df['Latitude']=Latitude_list
df['Longitude']=Longitude_list

# %%
df.head()
# Out:
#   Neighourhood                     London borough       Post town  \
# 0   Abbey Wood              Bexley, Greenwich [7]          LONDON
# 1        Acton  Ealing, Hammersmith and Fulham[8]          LONDON
# 2    Addington                         Croydon[8]         CROYDON
# 3   Addiscombe                         Croydon[8]         CROYDON
# 4  Albany Park                             Bexley  BEXLEY, SIDCUP
#
#   Postcode district Dial code OS grid ref
# 0               SE2       020    TQ465785
# 1            W3, W4       020    TQ205805
# 2               CR0       020    TQ375645
# 3               CR0       020    TQ345665
# 4         DA5, DA14       020    TQ478728

# %%
CLIENT_ID = 'CATVSEF43Z1JR3ZVH2ED2DL00CVECE5TNBAO0O5FZO4HX4PV' 
CLIENT_SECRET = 'FQTWJVLGTLZGXL1DN0W5FNK2YU0ONEXKOQJSLPHX2URYZHET' 
VERSION = '20180604' 
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: CATVSEF43Z1JR3ZVH2ED2DL00CVECE5TNBAO0O5FZO4HX4PV
# CLIENT_SECRET:FQTWJVLGTLZGXL1DN0W5FNK2YU0ONEXKOQJSLPHX2URYZHET

# %%
radius = 400000
LIMIT = 300

venues = []

for lat, long, neighbourhood in zip(df['Latitude'], df['Longitude'], df['Neighbourhood']):
    
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}".format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        lat,
        long,
        radius, 
        LIMIT)
    
       results = requests.get(url).json()["response"]['groups'][0]['items']
    
      for venue in results:
        venues.append((
            neighbourhood,
            lat, 
            long, 
            venue['venue']['name'], 
            venue['venue']['location']['lat'], 
            venue['venue']['location']['lng'],  
            venue['venue']['categories'][0]['name']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-140-80d5524a5b1a> in <module>
#       4 venues = []
#       5
# ----> 6 for lat, long, neighbourhood in zip(df['Latitude'], df['Longitude'], df['Neighbourhood']):
#       7
#       8     url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}".format(
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'

# %%
search_query = 'Italian'

print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=CATVSEF43Z1JR3ZVH2ED2DL00CVECE5TNBAO0O5FZO4HX4PV&client_secret=FQTWJVLGTLZGXL1DN0W5FNK2YU0ONEXKOQJSLPHX2URYZHET&ll=51.5073219,-0.1276474&v=20180604&query=Italian&radius=4000000000000000000000000000000000000000000000000&limit=30000000000000000000000000'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5deeb3099388d7001be6d168'},
#  'response': {'venues': [{'id': '4c54126830f92d7f9f71d2b9',
#     'name': 'ASK Italian',
#     'location': {'address': '121 - 125 Park St',
#      'lat': 51.5133638,
#      'lng': -0.155954,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5133638,
#        'lng': -0.155954}],
#      'distance': 2073,
#      'postalCode': 'W1K 7JA',
#      'cc': 'GB',
#      'city': 'Mayfair',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['121 - 125 Park St',
#       'Mayfair',
#       'Greater London',
#       'W1K 7JA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4ac518edf964a520c0ac20e3',
#     'name': 'Italian Bookshop',
#     'location': {'address': '5 Cecil Court',
#      'lat': 51.510778341568894,
#      'lng': -0.1275219512607079,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.510778341568894,
#        'lng': -0.1275219512607079}],
#      'distance': 384,
#      'postalCode': 'WC2N 4EZ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['5 Cecil Court',
#       'London',
#       'Greater London',
#       'WC2N 4EZ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d114951735',
#       'name': 'Bookstore',
#       'pluralName': 'Bookstores',
#       'shortName': 'Bookstore',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4e805fb2dab41c952c505ffc',
#     'name': 'Novikov',
#     'location': {'address': '50a Berkeley St',
#      'lat': 51.507767103762376,
#      'lng': -0.14284957683152608,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.507767103762376,
#        'lng': -0.14284957683152608}],
#      'distance': 1054,
#      'postalCode': 'W1J 8HA',
#      'cc': 'GB',
#      'neighborhood': 'Mayfair',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['50a Berkeley St',
#       'London',
#       'Greater London',
#       'W1J 8HA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '121043084'},
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '535e72ce498e70b6d38ba610',
#     'name': 'Beboz Italian Street Food',
#     'location': {'address': '60c Holborn Viaduct',
#      'lat': 51.51697997134506,
#      'lng': -0.10424082851639255,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51697997134506,
#        'lng': -0.10424082851639255}],
#      'distance': 1945,
#      'postalCode': 'EC1A 2FD',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['60c Holborn Viaduct',
#       'London',
#       'Greater London',
#       'EC1A 2FD',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '132860391'},
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4eb026469a521bacdb927d65',
#     'name': 'Billionaire Italian Couture',
#     'location': {'address': '9 Sloane St',
#      'lat': 51.50645206211797,
#      'lng': -0.14036953274956782,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50645206211797,
#        'lng': -0.14036953274956782}],
#      'distance': 886,
#      'postalCode': 'SW1X 9LE',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['9 Sloane St',
#       'London',
#       'Greater London',
#       'SW1X 9LE',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4c62d713ec94a5932e3d2aca',
#     'name': 'Prezzo Italian Restaurant London St Martins Lane',
#     'location': {'address': "116 Saint Martin's Ln",
#      'lat': 51.50940280181761,
#      'lng': -0.12712713136183257,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50940280181761,
#        'lng': -0.12712713136183257}],
#      'distance': 234,
#      'postalCode': 'WC2N 4BD',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'formattedAddress': ["116 Saint Martin's Ln",
#       'London',
#       'WC2N 4BD',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '57f3baea498efae5781eca28',
#     'name': 'The Italian Job',
#     'location': {'address': '40-42 Newington Causeway',
#      'lat': 51.49871478592709,
#      'lng': -0.09903581206029025,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49871478592709,
#        'lng': -0.09903581206029025}],
#      'distance': 2201,
#      'postalCode': 'SE1 6DR',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['40-42 Newington Causeway',
#       'London',
#       'Greater London',
#       'SE1 6DR',
#       'United Kingdom']},
#     'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#       'name': 'Beer Bar',
#       'pluralName': 'Beer Bars',
#       'shortName': 'Beer Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '5b266200066332001c011f5e',
#     'name': 'Vespa Italian Restaurant',
#     'location': {'address': '9a Irving St',
#      'lat': 51.509867,
#      'lng': -0.12877,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.509867,
#        'lng': -0.12877}],
#      'distance': 293,
#      'postalCode': 'WC2H 7AH',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['9a Irving St',
#       'London',
#       'Greater London',
#       'WC2H 7AH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4ac518cdf964a520e6a520e3',
#     'name': 'National Gallery',
#     'location': {'address': 'Trafalgar Sq',
#      'lat': 51.50887601013219,
#      'lng': -0.1284778118133545,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50887601013219,
#        'lng': -0.1284778118133545}],
#      'distance': 182,
#      'postalCode': 'WC2N 5DN',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Trafalgar Sq',
#       'London',
#       'Greater London',
#       'WC2N 5DN',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d18f941735',
#       'name': 'Art Museum',
#       'pluralName': 'Art Museums',
#       'shortName': 'Art Museum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '51313653'},
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '56c33025cd106d138c68f947',
#     'name': 'italian furniture london',
#     'location': {'lat': 51.50864897264021,
#      'lng': -0.12683629989624023,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50864897264021,
#        'lng': -0.12683629989624023}],
#      'distance': 158,
#      'postalCode': 'HA9',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London',
#       'Greater London',
#       'HA9',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'shortName': 'Furniture / Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '56f2e13f498e3fa61428dbda',
#     'name': 'italian sofas',
#     'location': {'address': '10 Charles II St.',
#      'lat': 51.50862226227263,
#      'lng': -0.12574195861816406,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50862226227263,
#        'lng': -0.12574195861816406}],
#      'distance': 195,
#      'postalCode': 'SW1Y 4AA',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['10 Charles II St.',
#       'London',
#       'Greater London',
#       'SW1Y 4AA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'shortName': 'Furniture / Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '5808aad8d67c3078bbf7b7ea',
#     'name': 'Italian Sausage Bap',
#     'location': {'address': 'Mercato Metripolitano, 42 Newington Causeway',
#      'lat': 51.49875,
#      'lng': -0.0986037,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49875,
#        'lng': -0.0986037}],
#      'distance': 2227,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Mercato Metripolitano, 42 Newington Causeway',
#       'United Kingdom']},
#     'categories': [{'id': '56aa371be4b08b9a8d57350b',
#       'name': 'Food Stand',
#       'pluralName': 'Food Stands',
#       'shortName': 'Food Stand',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/movingtarget_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4f1d2ccae4b0b4fdeb099d24',
#     'name': 'Italian Trade Commission',
#     'location': {'lat': 51.50731813081303,
#      'lng': -0.13268501164215557,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50731813081303,
#        'lng': -0.13268501164215557}],
#      'distance': 349,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London', 'Greater London', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'shortName': 'Government',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4dd15b09d4c065592fc433d5',
#     'name': 'Pepe Italian Street Food',
#     'location': {'address': "57 St. Martin's Ln",
#      'lat': 51.510925328709014,
#      'lng': -0.1270326607935119,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.510925328709014,
#        'lng': -0.1270326607935119}],
#      'distance': 403,
#      'postalCode': 'WC2N 4EA',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ["57 St. Martin's Ln",
#       'London',
#       'Greater London',
#       'WC2N 4EA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4cade4f32a55224b431d7269',
#     'name': 'Italian Pizzeria',
#     'location': {'lat': 51.51124228578267,
#      'lng': -0.1299014804195261,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51124228578267,
#        'lng': -0.1299014804195261}],
#      'distance': 463,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4d12331f804a2d43abc192e3',
#     'name': "St Peter's Italian Church",
#     'location': {'address': '136 Clerkenwell Rd',
#      'lat': 51.52220283972082,
#      'lng': -0.1089828940812208,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52220283972082,
#        'lng': -0.1089828940812208}],
#      'distance': 2101,
#      'postalCode': 'EC1R 5DL',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['136 Clerkenwell Rd',
#       'London',
#       'Greater London',
#       'EC1R 5DL',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4f50da0de4b0571ec4c66cf6',
#     'name': 'Italian Jacks',
#     'location': {'address': 'South Bank',
#      'lat': 51.506592740933954,
#      'lng': -0.11991957459053453,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.506592740933954,
#        'lng': -0.11991957459053453}],
#      'distance': 541,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['South Bank',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c9941735',
#       'name': 'Ice Cream Shop',
#       'pluralName': 'Ice Cream Shops',
#       'shortName': 'Ice Cream',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '506729cde4b0cdb22fe75372',
#     'name': 'Amici Italian Restaurant, Courtyard & Wine Bar',
#     'location': {'address': '205-209 Kennington Lane',
#      'lat': 51.48752578470624,
#      'lng': -0.1117614609167371,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.48752578470624,
#        'lng': -0.1117614609167371}],
#      'distance': 2463,
#      'postalCode': 'SE11 4LD',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['205-209 Kennington Lane',
#       'London',
#       'Greater London',
#       'SE11 4LD',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '76188164'},
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4ac518d3f964a52051a720e3',
#     'name': 'Italian Cultural Institute in London',
#     'location': {'address': '39 Belgrave Square',
#      'lat': 51.4995151680834,
#      'lng': -0.1519759184553437,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.4995151680834,
#        'lng': -0.1519759184553437}],
#      'distance': 1896,
#      'postalCode': 'SW1X 8NX',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['39 Belgrave Square',
#       'London',
#       'Greater London',
#       'SW1X 8NX',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4b49f8ccf964a520fa7626e3',
#     'name': 'ASK Italian',
#     'location': {'address': '56-60 Wigmore St',
#      'lat': 51.51637141742661,
#      'lng': -0.14962261549032974,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51637141742661,
#        'lng': -0.14962261549032974}],
#      'distance': 1825,
#      'postalCode': 'W1U 2RZ',
#      'cc': 'GB',
#      'city': 'Marylebone',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['56-60 Wigmore St',
#       'Marylebone',
#       'Greater London',
#       'W1U 2RZ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4ac518ddf964a52070a920e3',
#     'name': 'Italian Kitchen',
#     'location': {'address': '43 New Oxford Street',
#      'lat': 51.51713783370833,
#      'lng': -0.1254220863226059,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51713783370833,
#        'lng': -0.1254220863226059}],
#      'distance': 1103,
#      'postalCode': 'WC1A 1BH',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['43 New Oxford Street',
#       'London',
#       'Greater London',
#       'WC1A 1BH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '5cc6f5469ba3e5002c677866',
#     'name': 'Beboz Italian Street Food',
#     'location': {'address': 'Unit 1, SouthBank Tower',
#      'lat': 51.50781,
#      'lng': -0.107163,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50781,
#        'lng': -0.107163}],
#      'distance': 1420,
#      'postalCode': 'SE1 9LS',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Unit 1, SouthBank Tower',
#       'London',
#       'Greater London',
#       'SE1 9LS',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '5ca65e19a42362002c9c5f0f',
#     'name': 'Italian Punto Food LTD',
#     'location': {'address': "26 Foubert's Pl",
#      'lat': 51.5137011,
#      'lng': -0.13912949999996727,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5137011,
#        'lng': -0.13912949999996727}],
#      'distance': 1066,
#      'postalCode': 'W1B',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ["26 Foubert's Pl",
#       'London',
#       'Greater London',
#       'W1B',
#       'United Kingdom']},
#     'categories': [{'id': '5453de49498eade8af355881',
#       'name': 'Business Service',
#       'pluralName': 'Business Services',
#       'shortName': 'Business Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '536258614'},
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4dfa666352b1a82364e67dae',
#     'name': 'River Lounge Italian',
#     'location': {'address': "50 St Katharine's Way",
#      'lat': 51.50640920962762,
#      'lng': -0.07183391851485448,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50640920962762,
#        'lng': -0.07183391851485448}],
#      'distance': 3868,
#      'postalCode': 'E1W 1LA',
#      'cc': 'GB',
#      'city': "St. Katharine's and Wapping",
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ["50 St Katharine's Way",
#       "St. Katharine's and Wapping",
#       'Greater London',
#       'E1W 1LA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4c39e5c31e06d13a4b467a3e',
#     'name': 'Italian Gardens',
#     'location': {'address': 'Lancaster Gate',
#      'lat': 51.51084390978169,
#      'lng': -0.17557551589492673,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51084390978169,
#        'lng': -0.17557551589492673}],
#      'distance': 3343,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Lancaster Gate',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4c98bb1e671db60c40b8bbf6',
#     'name': "Ponti's Italian Kitchen",
#     'location': {'address': '5-7 John Princes St',
#      'lat': 51.51578169241686,
#      'lng': -0.14266948449469766,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51578169241686,
#        'lng': -0.14266948449469766}],
#      'distance': 1403,
#      'postalCode': 'W1G 0JN',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['5-7 John Princes St',
#       'London',
#       'Greater London',
#       'W1G 0JN',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4cb56d6c52edb1f7644367fe',
#     'name': 'Italian Consolate',
#     'location': {'address': '136,Buckingham palace',
#      'lat': 51.50173700288803,
#      'lng': -0.14208912888956002,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50173700288803,
#        'lng': -0.14208912888956002}],
#      'distance': 1178,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['136,Buckingham palace',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '5783e162498e42a899db503d',
#     'name': 'Italian Gardens Café',
#     'location': {'address': 'Bayswater Rd',
#      'crossStreet': 'at Lancaster Ter',
#      'lat': 51.51129827942295,
#      'lng': -0.1754637084975213,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51129827942295,
#        'lng': -0.1754637084975213}],
#      'distance': 3342,
#      'postalCode': 'W2 2UE',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Bayswater Rd (at Lancaster Ter)',
#       'London',
#       'Greater London',
#       'W2 2UE',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '56af4991498efe2039511107',
#     'name': 'italian tourist board',
#     'location': {'lat': 51.51464,
#      'lng': -0.142155,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51464,
#        'lng': -0.142155}],
#      'distance': 1293,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4f4530164b9074f6e4fb00ff',
#       'name': 'Tourist Information Center',
#       'pluralName': 'Tourist Information Centers',
#       'shortName': 'Tourist Information',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/touristinformation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4bf311a4c440c9b6cb840104',
#     'name': 'Colosseo Italian Restaurant',
#     'location': {'address': '79 Victoria St.',
#      'lat': 51.49771908750752,
#      'lng': -0.13501867365092737,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49771908750752,
#        'lng': -0.13501867365092737}],
#      'distance': 1184,
#      'postalCode': 'SW1H 0HW',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['79 Victoria St.',
#       'London',
#       'Greater London',
#       'SW1H 0HW',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4b79441ef964a52071f12ee3',
#     'name': 'ASK Italian',
#     'location': {'address': 'Business Design Centre',
#      'crossStreet': '52 Upper St',
#      'lat': 51.53543470173844,
#      'lng': -0.1049150261629482,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.53543470173844,
#        'lng': -0.1049150261629482}],
#      'distance': 3503,
#      'postalCode': 'N1 0PN',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Business Design Centre (52 Upper St)',
#       'London',
#       'Greater London',
#       'N1 0PN',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '51d3e35e498efa52d5e6adad',
#     'name': 'Italian Consulate',
#     'location': {'address': '83/86 Farringdon St',
#      'lat': 51.51520359544737,
#      'lng': -0.10453962886060657,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51520359544737,
#        'lng': -0.10453962886060657}],
#      'distance': 1825,
#      'postalCode': 'EC4A 4BL',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['83/86 Farringdon St',
#       'London',
#       'Greater London',
#       'EC4A 4BL',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d12c951735',
#       'name': 'Embassy / Consulate',
#       'pluralName': 'Embassies / Consulates',
#       'shortName': 'Embassy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/embassy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '500fc052e4b0c0d1a8f1ccd6',
#     'name': 'Maxelâ Italian Butcher & Restaurant',
#     'location': {'address': '84 Old Brompton Rd',
#      'lat': 51.4925825400316,
#      'lng': -0.17736952144682874,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.4925825400316,
#        'lng': -0.17736952144682874}],
#      'distance': 3816,
#      'postalCode': 'SW7 3LQ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['84 Old Brompton Rd',
#       'London',
#       'Greater London',
#       'SW7 3LQ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '5a2ebc598496ca1be80c5645',
#     'name': 'The Italian Medical Centre',
#     'location': {'address': '58 South Molton Street',
#      'lat': 51.513382,
#      'lng': -0.147379,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.513382,
#        'lng': -0.147379}],
#      'distance': 1524,
#      'postalCode': 'W1K 5SL',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['58 South Molton Street',
#       'London',
#       'Greater London',
#       'W1K 5SL',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '5c45c16c66fc650039c0cc4d',
#     'name': 'Beboz Italian Street Food',
#     'location': {'address': '35 Maddox Street',
#      'lat': 51.512753,
#      'lng': -0.142316,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.512753,
#        'lng': -0.142316}],
#      'distance': 1182,
#      'postalCode': 'W1S 1PF',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['35 Maddox Street',
#       'London',
#       'Greater London',
#       'W1S 1PF',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4d10b844c3dc370465f63a74',
#     'name': 'Borgia Italian Restaurant',
#     'location': {'lat': 51.50419234,
#      'lng': -0.1149375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50419234,
#        'lng': -0.1149375}],
#      'distance': 947,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4b7d2afef964a52027b12fe3',
#     'name': 'Italian Consulate General',
#     'location': {'address': '38 Eaton Pl',
#      'lat': 51.49715643571649,
#      'lng': -0.15226763625448286,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49715643571649,
#        'lng': -0.15226763625448286}],
#      'distance': 2047,
#      'postalCode': 'SW1X 8AN',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['38 Eaton Pl',
#       'London',
#       'Greater London',
#       'SW1X 8AN',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d12c951735',
#       'name': 'Embassy / Consulate',
#       'pluralName': 'Embassies / Consulates',
#       'shortName': 'Embassy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/embassy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '58778ff98ae36303ee20c4ca',
#     'name': "Marco's New York Italian",
#     'location': {'address': '130-134 Southampton Row',
#      'lat': 51.520882,
#      'lng': -0.123197,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.520882,
#        'lng': -0.123197}],
#      'distance': 1540,
#      'postalCode': 'WC1B 5AF',
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['130-134 Southampton Row',
#       'WC1B 5AF',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '5cfa40d0cabcff002c86e8f3',
#     'name': 'IL E DE CREPE Events & Italian Pancakes',
#     'location': {'address': '3 Hay Hill London',
#      'lat': 51.50905964257018,
#      'lng': -0.14348745346069336,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50905964257018,
#        'lng': -0.14348745346069336}],
#      'distance': 1114,
#      'postalCode': 'W1J 6AS',
#      'cc': 'GB',
#      'city': 'Mayfair',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['3 Hay Hill London',
#       'Mayfair',
#       'Greater London',
#       'W1J 6AS',
#       'United Kingdom']},
#     'categories': [{'id': '56aa371be4b08b9a8d573550',
#       'name': 'Food Service',
#       'pluralName': 'Food Services',
#       'shortName': 'Food Service',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '59c012144186867189685c68',
#     'name': "Marco's New York Italian",
#     'location': {'address': '12-20 Osborn St',
#      'lat': 51.516602,
#      'lng': -0.070002,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.516602,
#        'lng': -0.070002}],
#      'distance': 4125,
#      'postalCode': 'E1 6TD',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['12-20 Osborn St',
#       'London',
#       'Greater London',
#       'E1 6TD',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '544c6f32498eb6077fab80c6',
#     'name': 'Da’Paolo Italian Restaurant',
#     'location': {'address': '3 Charlotte Place',
#      'lat': 51.51895094090855,
#      'lng': -0.13614100420031822,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51895094090855,
#        'lng': -0.13614100420031822}],
#      'distance': 1421,
#      'postalCode': 'W1T 1SD',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['3 Charlotte Place',
#       'London',
#       'Greater London',
#       'W1T 1SD',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '54282fb2498e4c803e3ced89',
#     'name': 'franco italian taylor',
#     'location': {'address': '26 kingly Street',
#      'lat': 51.513038,
#      'lng': -0.140062,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.513038,
#        'lng': -0.140062}],
#      'distance': 1069,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['26 kingly Street', 'United Kingdom']},
#     'categories': [{'id': '5032781d91d4c4b30a586d5b',
#       'name': 'Tailor Shop',
#       'pluralName': 'Tailor Shops',
#       'shortName': 'Tailor',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4c39e6ffdfb0e21e3022b1a8',
#     'name': 'Italian Fountains',
#     'location': {'address': 'Lancaster Gate',
#      'crossStreet': 'Italian Gardens',
#      'lat': 51.510545368712286,
#      'lng': -0.17550230026245117,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.510545368712286,
#        'lng': -0.17550230026245117}],
#      'distance': 3334,
#      'postalCode': 'W2 4RQ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Lancaster Gate (Italian Gardens)',
#       'London',
#       'Greater London',
#       'W2 4RQ',
#       'United Kingdom']},
#     'categories': [{'id': '56aa371be4b08b9a8d573547',
#       'name': 'Fountain',
#       'pluralName': 'Fountains',
#       'shortName': 'Fountain',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4c10c0d53ce120a16b80081c',
#     'name': 'Italian Cafe',
#     'location': {'address': '4 Exeter Parade',
#      'crossStreet': 'Exeter Rd',
#      'lat': 51.547187726036526,
#      'lng': -0.204165412956446,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.547187726036526,
#        'lng': -0.204165412956446}],
#      'distance': 6912,
#      'postalCode': 'NW2 3UH',
#      'cc': 'GB',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['4 Exeter Parade (Exeter Rd)',
#       'Kilburn',
#       'Greater London',
#       'NW2 3UH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '57910a85498e67a97b93582d',
#     'name': 'Happy Languages - Italian',
#     'location': {'lat': 51.518336,
#      'lng': -0.122619,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.518336,
#        'lng': -0.122619}],
#      'distance': 1274,
#      'postalCode': 'W C1A',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London',
#       'Greater London',
#       'W C1A',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'shortName': 'Classroom',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4ffe9ee6e4b0bd73f92115e3',
#     'name': 'Italian Notary Office',
#     'location': {'address': '136 Buckingham Palace Rd.',
#      'lat': 51.49257150778605,
#      'lng': -0.14741173450460807,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49257150778605,
#        'lng': -0.14741173450460807}],
#      'distance': 2138,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['136 Buckingham Palace Rd.',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '5ae95d208a6f17002ce792b2',
#       'name': 'Notary',
#       'pluralName': 'Notaries',
#       'shortName': 'Notary',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lawschool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '54db4d49498e2da1c882339f',
#     'name': 'Ciao - Italian Street Food',
#     'location': {'address': '35-37 Maddox Street',
#      'lat': 51.512789675655334,
#      'lng': -0.1424261574288319,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.512789675655334,
#        'lng': -0.1424261574288319}],
#      'distance': 1191,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['35-37 Maddox Street', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '4bcb4252fb84c9b65d6f1e3e',
#     'name': 'ASK Italian',
#     'location': {'address': '85 Kew Green',
#      'lat': 51.485464811243304,
#      'lng': -0.2878229201968452,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.485464811243304,
#        'lng': -0.2878229201968452}],
#      'distance': 11364,
#      'postalCode': 'TW9 3AH',
#      'cc': 'GB',
#      'city': 'Surrey',
#      'state': 'Surrey',
#      'country': 'United Kingdom',
#      'formattedAddress': ['85 Kew Green',
#       'Surrey',
#       'TW9 3AH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '504b9a26e4b037e085838b72',
#     'name': 'Italian supernice houseparty',
#     'location': {'lat': 51.524626,
#      'lng': -0.105057,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.524626,
#        'lng': -0.105057}],
#      'distance': 2481,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False},
#    {'id': '53bef18a498e315d4dc099af',
#     'name': 'Parlando Italiano My Italian Lessons',
#     'location': {'address': '283-288 High Holborn',
#      'lat': 51.51792987720294,
#      'lng': -0.11451959609985352,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51792987720294,
#        'lng': -0.11451959609985352}],
#      'distance': 1490,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['283-288 High Holborn',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575924515',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 1  [{'id': '4bf58dd8d48988d114951735', 'name': 'B...    False
# 2  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 4  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...    False
#
#                          id     location.address location.cc location.city  \
# 0  4c54126830f92d7f9f71d2b9    121 - 125 Park St          GB       Mayfair
# 1  4ac518edf964a520c0ac20e3        5 Cecil Court          GB        London
# 2  4e805fb2dab41c952c505ffc      50a Berkeley St          GB        London
# 3  535e72ce498e70b6d38ba610  60c Holborn Viaduct          GB        London
# 4  4eb026469a521bacdb927d65          9 Sloane St          GB        London
#
#   location.country location.crossStreet  location.distance  \
# 0   United Kingdom                  NaN               2073
# 1   United Kingdom                  NaN                384
# 2   United Kingdom                  NaN               1054
# 3   United Kingdom                  NaN               1945
# 4   United Kingdom                  NaN                886
#
#                            location.formattedAddress  \
# 0  [121 - 125 Park St, Mayfair, Greater London, W...
# 1  [5 Cecil Court, London, Greater London, WC2N 4...
# 2  [50a Berkeley St, London, Greater London, W1J ...
# 3  [60c Holborn Viaduct, London, Greater London, ...
# 4  [9 Sloane St, London, Greater London, SW1X 9LE...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 51.5133638, 'lng'...     51.513364
# 1  [{'label': 'display', 'lat': 51.51077834156889...     51.510778
# 2  [{'label': 'display', 'lat': 51.50776710376237...     51.507767
# 3  [{'label': 'display', 'lat': 51.51697997134506...     51.516980
# 4  [{'label': 'display', 'lat': 51.50645206211797...     51.506452
#
#    location.lng location.neighborhood location.postalCode  location.state  \
# 0     -0.155954                   NaN             W1K 7JA  Greater London
# 1     -0.127522                   NaN            WC2N 4EZ  Greater London
# 2     -0.142850               Mayfair             W1J 8HA  Greater London
# 3     -0.104241                   NaN            EC1A 2FD  Greater London
# 4     -0.140370                   NaN            SW1X 9LE  Greater London
#
#                           name    referralId venuePage.id
# 0                  ASK Italian  v-1575924515          NaN
# 1             Italian Bookshop  v-1575924515          NaN
# 2                      Novikov  v-1575924515    121043084
# 3    Beboz Italian Street Food  v-1575924515    132860391
# 4  Billionaire Italian Couture  v-1575924515          NaN

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                 name  \
# 0                                        ASK Italian
# 1                                   Italian Bookshop
# 2                                            Novikov
# 3                          Beboz Italian Street Food
# 4                        Billionaire Italian Couture
# 5   Prezzo Italian Restaurant London St Martins Lane
# 6                                    The Italian Job
# 7                           Vespa Italian Restaurant
# 8                                   National Gallery
# 9                           italian furniture london
# 10                                     italian sofas
# 11                               Italian Sausage Bap
# 12                          Italian Trade Commission
# 13                          Pepe Italian Street Food
# 14                                  Italian Pizzeria
# 15                         St Peter's Italian Church
# 16                                     Italian Jacks
# 17    Amici Italian Restaurant, Courtyard & Wine Bar
# 18              Italian Cultural Institute in London
# 19                                       ASK Italian
# 20                                   Italian Kitchen
# 21                         Beboz Italian Street Food
# 22                            Italian Punto Food LTD
# 23                              River Lounge Italian
# 24                                   Italian Gardens
# 25                           Ponti's Italian Kitchen
# 26                                 Italian Consolate
# 27                              Italian Gardens Café
# 28                             italian tourist board
# 29                       Colosseo Italian Restaurant
# 30                                       ASK Italian
# 31                                 Italian Consulate
# 32               Maxelâ Italian Butcher & Restaurant
# 33                        The Italian Medical Centre
# 34                         Beboz Italian Street Food
# 35                         Borgia Italian Restaurant
# 36                         Italian Consulate General
# 37                          Marco's New York Italian
# 38           IL E DE CREPE Events & Italian Pancakes
# 39                          Marco's New York Italian
# 40                       Da’Paolo Italian Restaurant
# 41                             franco italian taylor
# 42                                 Italian Fountains
# 43                                      Italian Cafe
# 44                         Happy Languages - Italian
# 45                             Italian Notary Office
# 46                        Ciao - Italian Street Food
# 47                                       ASK Italian
# 48                      Italian supernice houseparty
# 49              Parlando Italiano My Italian Lessons
#
#                     categories                                       address  \
# 0           Italian Restaurant                             121 - 125 Park St
# 1                    Bookstore                                 5 Cecil Court
# 2             Asian Restaurant                               50a Berkeley St
# 3           Italian Restaurant                           60c Holborn Viaduct
# 4               Clothing Store                                   9 Sloane St
# 5           Italian Restaurant                         116 Saint Martin's Ln
# 6                     Beer Bar                      40-42 Newington Causeway
# 7           Italian Restaurant                                  9a Irving St
# 8                   Art Museum                                  Trafalgar Sq
# 9       Furniture / Home Store                                           NaN
# 10      Furniture / Home Store                             10 Charles II St.
# 11                  Food Stand  Mercato Metripolitano, 42 Newington Causeway
# 12         Government Building                                           NaN
# 13          Italian Restaurant                            57 St. Martin's Ln
# 14                 Pizza Place                                           NaN
# 15                      Church                            136 Clerkenwell Rd
# 16              Ice Cream Shop                                    South Bank
# 17          Italian Restaurant                       205-209 Kennington Lane
# 18                 Event Space                            39 Belgrave Square
# 19          Italian Restaurant                              56-60 Wigmore St
# 20          Italian Restaurant                          43 New Oxford Street
# 21          Italian Restaurant                       Unit 1, SouthBank Tower
# 22            Business Service                               26 Foubert's Pl
# 23          Italian Restaurant                         50 St Katharine's Way
# 24                      Garden                                Lancaster Gate
# 25          Italian Restaurant                           5-7 John Princes St
# 26                      Office                         136,Buckingham palace
# 27                        Café                                  Bayswater Rd
# 28  Tourist Information Center                                           NaN
# 29          Italian Restaurant                               79 Victoria St.
# 30          Italian Restaurant                        Business Design Centre
# 31         Embassy / Consulate                           83/86 Farringdon St
# 32                  Steakhouse                            84 Old Brompton Rd
# 33              Medical Center                        58 South Molton Street
# 34          Italian Restaurant                              35 Maddox Street
# 35                        None                                           NaN
# 36         Embassy / Consulate                                   38 Eaton Pl
# 37          Italian Restaurant                       130-134 Southampton Row
# 38                Food Service                             3 Hay Hill London
# 39          Italian Restaurant                               12-20 Osborn St
# 40          Italian Restaurant                             3 Charlotte Place
# 41                 Tailor Shop                              26 kingly Street
# 42                    Fountain                                Lancaster Gate
# 43                        Café                               4 Exeter Parade
# 44           College Classroom                                           NaN
# 45                      Notary                     136 Buckingham Palace Rd.
# 46          Italian Restaurant                           35-37 Maddox Street
# 47          Italian Restaurant                                  85 Kew Green
# 48          Italian Restaurant                                           NaN
# 49             Language School                          283-288 High Holborn
#
#     cc                         city         country       crossStreet  \
# 0   GB                      Mayfair  United Kingdom               NaN
# 1   GB                       London  United Kingdom               NaN
# 2   GB                       London  United Kingdom               NaN
# 3   GB                       London  United Kingdom               NaN
# 4   GB                       London  United Kingdom               NaN
# 5   GB                       London  United Kingdom               NaN
# 6   GB                       London  United Kingdom               NaN
# 7   GB                       London  United Kingdom               NaN
# 8   GB                       London  United Kingdom               NaN
# 9   GB                       London  United Kingdom               NaN
# 10  GB                       London  United Kingdom               NaN
# 11  GB                          NaN  United Kingdom               NaN
# 12  GB                       London  United Kingdom               NaN
# 13  GB                       London  United Kingdom               NaN
# 14  GB                          NaN  United Kingdom               NaN
# 15  GB                       London  United Kingdom               NaN
# 16  GB                       London  United Kingdom               NaN
# 17  GB                       London  United Kingdom               NaN
# 18  GB                       London  United Kingdom               NaN
# 19  GB                   Marylebone  United Kingdom               NaN
# 20  GB                       London  United Kingdom               NaN
# 21  GB                       London  United Kingdom               NaN
# 22  GB                       London  United Kingdom               NaN
# 23  GB  St. Katharine's and Wapping  United Kingdom               NaN
# 24  GB                       London  United Kingdom               NaN
# 25  GB                       London  United Kingdom               NaN
# 26  GB                       London  United Kingdom               NaN
# 27  GB                       London  United Kingdom  at Lancaster Ter
# 28  GB                          NaN  United Kingdom               NaN
# 29  GB                       London  United Kingdom               NaN
# 30  GB                       London  United Kingdom       52 Upper St
# 31  GB                       London  United Kingdom               NaN
# 32  GB                       London  United Kingdom               NaN
# 33  GB                       London  United Kingdom               NaN
# 34  GB                       London  United Kingdom               NaN
# 35  GB                          NaN  United Kingdom               NaN
# 36  GB                       London  United Kingdom               NaN
# 37  GB                          NaN  United Kingdom               NaN
# 38  GB                      Mayfair  United Kingdom               NaN
# 39  GB                       London  United Kingdom               NaN
# 40  GB                       London  United Kingdom               NaN
# 41  GB                          NaN  United Kingdom               NaN
# 42  GB                       London  United Kingdom   Italian Gardens
# 43  GB                          NaN  United Kingdom         Exeter Rd
# 44  GB                       London  United Kingdom               NaN
# 45  GB                       London  United Kingdom               NaN
# 46  GB                          NaN  United Kingdom               NaN
# 47  GB                       Surrey  United Kingdom               NaN
# 48  GB                          NaN  United Kingdom               NaN
# 49  GB                       London  United Kingdom               NaN
#
#     distance                                   formattedAddress  \
# 0       2073  [121 - 125 Park St, Mayfair, Greater London, W...
# 1        384  [5 Cecil Court, London, Greater London, WC2N 4...
# 2       1054  [50a Berkeley St, London, Greater London, W1J ...
# 3       1945  [60c Holborn Viaduct, London, Greater London, ...
# 4        886  [9 Sloane St, London, Greater London, SW1X 9LE...
# 5        234  [116 Saint Martin's Ln, London, WC2N 4BD, Unit...
# 6       2201  [40-42 Newington Causeway, London, Greater Lon...
# 7        293  [9a Irving St, London, Greater London, WC2H 7A...
# 8        182  [Trafalgar Sq, London, Greater London, WC2N 5D...
# 9        158      [London, Greater London, HA9, United Kingdom]
# 10       195  [10 Charles II St., London, Greater London, SW...
# 11      2227  [Mercato Metripolitano, 42 Newington Causeway,...
# 12       349           [London, Greater London, United Kingdom]
# 13       403  [57 St. Martin's Ln, London, Greater London, W...
# 14       463                                   [United Kingdom]
# 15      2101  [136 Clerkenwell Rd, London, Greater London, E...
# 16       541  [South Bank, London, Greater London, United Ki...
# 17      2463  [205-209 Kennington Lane, London, Greater Lond...
# 18      1896  [39 Belgrave Square, London, Greater London, S...
# 19      1825  [56-60 Wigmore St, Marylebone, Greater London,...
# 20      1103  [43 New Oxford Street, London, Greater London,...
# 21      1420  [Unit 1, SouthBank Tower, London, Greater Lond...
# 22      1066  [26 Foubert's Pl, London, Greater London, W1B,...
# 23      3868  [50 St Katharine's Way, St. Katharine's and Wa...
# 24      3343  [Lancaster Gate, London, Greater London, Unite...
# 25      1403  [5-7 John Princes St, London, Greater London, ...
# 26      1178  [136,Buckingham palace, London, Greater London...
# 27      3342  [Bayswater Rd (at Lancaster Ter), London, Grea...
# 28      1293                                   [United Kingdom]
# 29      1184  [79 Victoria St., London, Greater London, SW1H...
# 30      3503  [Business Design Centre (52 Upper St), London,...
# 31      1825  [83/86 Farringdon St, London, Greater London, ...
# 32      3816  [84 Old Brompton Rd, London, Greater London, S...
# 33      1524  [58 South Molton Street, London, Greater Londo...
# 34      1182  [35 Maddox Street, London, Greater London, W1S...
# 35       947                                   [United Kingdom]
# 36      2047  [38 Eaton Pl, London, Greater London, SW1X 8AN...
# 37      1540  [130-134 Southampton Row, WC1B 5AF, United Kin...
# 38      1114  [3 Hay Hill London, Mayfair, Greater London, W...
# 39      4125  [12-20 Osborn St, London, Greater London, E1 6...
# 40      1421  [3 Charlotte Place, London, Greater London, W1...
# 41      1069                 [26 kingly Street, United Kingdom]
# 42      3334  [Lancaster Gate (Italian Gardens), London, Gre...
# 43      6912  [4 Exeter Parade (Exeter Rd), Kilburn, Greater...
# 44      1274    [London, Greater London, W C1A, United Kingdom]
# 45      2138  [136 Buckingham Palace Rd., London, Greater Lo...
# 46      1191              [35-37 Maddox Street, United Kingdom]
# 47     11364    [85 Kew Green, Surrey, TW9 3AH, United Kingdom]
# 48      2481                                   [United Kingdom]
# 49      1490  [283-288 High Holborn, London, Greater London,...
#
#                                        labeledLatLngs        lat       lng  \
# 0   [{'label': 'display', 'lat': 51.5133638, 'lng'...  51.513364 -0.155954
# 1   [{'label': 'display', 'lat': 51.51077834156889...  51.510778 -0.127522
# 2   [{'label': 'display', 'lat': 51.50776710376237...  51.507767 -0.142850
# 3   [{'label': 'display', 'lat': 51.51697997134506...  51.516980 -0.104241
# 4   [{'label': 'display', 'lat': 51.50645206211797...  51.506452 -0.140370
# 5   [{'label': 'display', 'lat': 51.50940280181761...  51.509403 -0.127127
# 6   [{'label': 'display', 'lat': 51.49871478592709...  51.498715 -0.099036
# 7   [{'label': 'display', 'lat': 51.509867, 'lng':...  51.509867 -0.128770
# 8   [{'label': 'display', 'lat': 51.50887601013219...  51.508876 -0.128478
# 9   [{'label': 'display', 'lat': 51.50864897264021...  51.508649 -0.126836
# 10  [{'label': 'display', 'lat': 51.50862226227263...  51.508622 -0.125742
# 11  [{'label': 'display', 'lat': 51.49875, 'lng': ...  51.498750 -0.098604
# 12  [{'label': 'display', 'lat': 51.50731813081303...  51.507318 -0.132685
# 13  [{'label': 'display', 'lat': 51.51092532870901...  51.510925 -0.127033
# 14  [{'label': 'display', 'lat': 51.51124228578267...  51.511242 -0.129901
# 15  [{'label': 'display', 'lat': 51.52220283972082...  51.522203 -0.108983
# 16  [{'label': 'display', 'lat': 51.50659274093395...  51.506593 -0.119920
# 17  [{'label': 'display', 'lat': 51.48752578470624...  51.487526 -0.111761
# 18  [{'label': 'display', 'lat': 51.4995151680834,...  51.499515 -0.151976
# 19  [{'label': 'display', 'lat': 51.51637141742661...  51.516371 -0.149623
# 20  [{'label': 'display', 'lat': 51.51713783370833...  51.517138 -0.125422
# 21  [{'label': 'display', 'lat': 51.50781, 'lng': ...  51.507810 -0.107163
# 22  [{'label': 'display', 'lat': 51.5137011, 'lng'...  51.513701 -0.139129
# 23  [{'label': 'display', 'lat': 51.50640920962762...  51.506409 -0.071834
# 24  [{'label': 'display', 'lat': 51.51084390978169...  51.510844 -0.175576
# 25  [{'label': 'display', 'lat': 51.51578169241686...  51.515782 -0.142669
# 26  [{'label': 'display', 'lat': 51.50173700288803...  51.501737 -0.142089
# 27  [{'label': 'display', 'lat': 51.51129827942295...  51.511298 -0.175464
# 28  [{'label': 'display', 'lat': 51.51464, 'lng': ...  51.514640 -0.142155
# 29  [{'label': 'display', 'lat': 51.49771908750752...  51.497719 -0.135019
# 30  [{'label': 'display', 'lat': 51.53543470173844...  51.535435 -0.104915
# 31  [{'label': 'display', 'lat': 51.51520359544737...  51.515204 -0.104540
# 32  [{'label': 'display', 'lat': 51.4925825400316,...  51.492583 -0.177370
# 33  [{'label': 'display', 'lat': 51.513382, 'lng':...  51.513382 -0.147379
# 34  [{'label': 'display', 'lat': 51.512753, 'lng':...  51.512753 -0.142316
# 35  [{'label': 'display', 'lat': 51.50419234, 'lng...  51.504192 -0.114937
# 36  [{'label': 'display', 'lat': 51.49715643571649...  51.497156 -0.152268
# 37  [{'label': 'display', 'lat': 51.520882, 'lng':...  51.520882 -0.123197
# 38  [{'label': 'display', 'lat': 51.50905964257018...  51.509060 -0.143487
# 39  [{'label': 'display', 'lat': 51.516602, 'lng':...  51.516602 -0.070002
# 40  [{'label': 'display', 'lat': 51.51895094090855...  51.518951 -0.136141
# 41  [{'label': 'display', 'lat': 51.513038, 'lng':...  51.513038 -0.140062
# 42  [{'label': 'display', 'lat': 51.51054536871228...  51.510545 -0.175502
# 43  [{'label': 'display', 'lat': 51.54718772603652...  51.547188 -0.204165
# 44  [{'label': 'display', 'lat': 51.518336, 'lng':...  51.518336 -0.122619
# 45  [{'label': 'display', 'lat': 51.49257150778605...  51.492572 -0.147412
# 46  [{'label': 'display', 'lat': 51.51278967565533...  51.512790 -0.142426
# 47  [{'label': 'display', 'lat': 51.48546481124330...  51.485465 -0.287823
# 48  [{'label': 'display', 'lat': 51.524626, 'lng':...  51.524626 -0.105057
# 49  [{'label': 'display', 'lat': 51.51792987720294...  51.517930 -0.114520
#
#    neighborhood postalCode           state                        id
# 0           NaN    W1K 7JA  Greater London  4c54126830f92d7f9f71d2b9
# 1           NaN   WC2N 4EZ  Greater London  4ac518edf964a520c0ac20e3
# 2       Mayfair    W1J 8HA  Greater London  4e805fb2dab41c952c505ffc
# 3           NaN   EC1A 2FD  Greater London  535e72ce498e70b6d38ba610
# 4           NaN   SW1X 9LE  Greater London  4eb026469a521bacdb927d65
# 5           NaN   WC2N 4BD             NaN  4c62d713ec94a5932e3d2aca
# 6           NaN    SE1 6DR  Greater London  57f3baea498efae5781eca28
# 7           NaN   WC2H 7AH  Greater London  5b266200066332001c011f5e
# 8           NaN   WC2N 5DN  Greater London  4ac518cdf964a520e6a520e3
# 9           NaN        HA9  Greater London  56c33025cd106d138c68f947
# 10          NaN   SW1Y 4AA  Greater London  56f2e13f498e3fa61428dbda
# 11          NaN        NaN             NaN  5808aad8d67c3078bbf7b7ea
# 12          NaN        NaN  Greater London  4f1d2ccae4b0b4fdeb099d24
# 13          NaN   WC2N 4EA  Greater London  4dd15b09d4c065592fc433d5
# 14          NaN        NaN             NaN  4cade4f32a55224b431d7269
# 15          NaN   EC1R 5DL  Greater London  4d12331f804a2d43abc192e3
# 16          NaN        NaN  Greater London  4f50da0de4b0571ec4c66cf6
# 17          NaN   SE11 4LD  Greater London  506729cde4b0cdb22fe75372
# 18          NaN   SW1X 8NX  Greater London  4ac518d3f964a52051a720e3
# 19          NaN    W1U 2RZ  Greater London  4b49f8ccf964a520fa7626e3
# 20          NaN   WC1A 1BH  Greater London  4ac518ddf964a52070a920e3
# 21          NaN    SE1 9LS  Greater London  5cc6f5469ba3e5002c677866
# 22          NaN        W1B  Greater London  5ca65e19a42362002c9c5f0f
# 23          NaN    E1W 1LA  Greater London  4dfa666352b1a82364e67dae
# 24          NaN        NaN  Greater London  4c39e5c31e06d13a4b467a3e
# 25          NaN    W1G 0JN  Greater London  4c98bb1e671db60c40b8bbf6
# 26          NaN        NaN  Greater London  4cb56d6c52edb1f7644367fe
# 27          NaN     W2 2UE  Greater London  5783e162498e42a899db503d
# 28          NaN        NaN             NaN  56af4991498efe2039511107
# 29          NaN   SW1H 0HW  Greater London  4bf311a4c440c9b6cb840104
# 30          NaN     N1 0PN  Greater London  4b79441ef964a52071f12ee3
# 31          NaN   EC4A 4BL  Greater London  51d3e35e498efa52d5e6adad
# 32          NaN    SW7 3LQ  Greater London  500fc052e4b0c0d1a8f1ccd6
# 33          NaN    W1K 5SL  Greater London  5a2ebc598496ca1be80c5645
# 34          NaN    W1S 1PF  Greater London  5c45c16c66fc650039c0cc4d
# 35          NaN        NaN             NaN  4d10b844c3dc370465f63a74
# 36          NaN   SW1X 8AN  Greater London  4b7d2afef964a52027b12fe3
# 37          NaN   WC1B 5AF             NaN  58778ff98ae36303ee20c4ca
# 38          NaN    W1J 6AS  Greater London  5cfa40d0cabcff002c86e8f3
# 39          NaN     E1 6TD  Greater London  59c012144186867189685c68
# 40          NaN    W1T 1SD  Greater London  544c6f32498eb6077fab80c6
# 41          NaN        NaN             NaN  54282fb2498e4c803e3ced89
# 42          NaN     W2 4RQ  Greater London  4c39e6ffdfb0e21e3022b1a8
# 43          NaN    NW2 3UH  Greater London  4c10c0d53ce120a16b80081c
# 44          NaN      W C1A  Greater London  57910a85498e67a97b93582d
# 45          NaN        NaN  Greater London  4ffe9ee6e4b0bd73f92115e3
# 46          NaN        NaN             NaN  54db4d49498e2da1c882339f
# 47          NaN    TW9 3AH          Surrey  4bcb4252fb84c9b65d6f1e3e
# 48          NaN        NaN             NaN  504b9a26e4b037e085838b72
# 49          NaN        NaN  Greater London  53bef18a498e315d4dc099af

# %%
dataframe_filtered.name
# Out:
# 0                                          ASK Italian
# 1                                     Italian Bookshop
# 2                                              Novikov
# 3                            Beboz Italian Street Food
# 4                          Billionaire Italian Couture
# 5     Prezzo Italian Restaurant London St Martins Lane
# 6                                      The Italian Job
# 7                             Vespa Italian Restaurant
# 8                                     National Gallery
# 9                             italian furniture london
# 10                                       italian sofas
# 11                                 Italian Sausage Bap
# 12                            Italian Trade Commission
# 13                            Pepe Italian Street Food
# 14                                    Italian Pizzeria
# 15                           St Peter's Italian Church
# 16                                       Italian Jacks
# 17      Amici Italian Restaurant, Courtyard & Wine Bar
# 18                Italian Cultural Institute in London
# 19                                         ASK Italian
# 20                                     Italian Kitchen
# 21                           Beboz Italian Street Food
# 22                              Italian Punto Food LTD
# 23                                River Lounge Italian
# 24                                     Italian Gardens
# 25                             Ponti's Italian Kitchen
# 26                                   Italian Consolate
# 27                                Italian Gardens Café
# 28                               italian tourist board
# 29                         Colosseo Italian Restaurant
# 30                                         ASK Italian
# 31                                   Italian Consulate
# 32                 Maxelâ Italian Butcher & Restaurant
# 33                          The Italian Medical Centre
# 34                           Beboz Italian Street Food
# 35                           Borgia Italian Restaurant
# 36                           Italian Consulate General
# 37                            Marco's New York Italian
# 38             IL E DE CREPE Events & Italian Pancakes
# 39                            Marco's New York Italian
# 40                         Da’Paolo Italian Restaurant
# 41                               franco italian taylor
# 42                                   Italian Fountains
# 43                                        Italian Cafe
# 44                           Happy Languages - Italian
# 45                               Italian Notary Office
# 46                          Ciao - Italian Street Food
# 47                                         ASK Italian
# 48                        Italian supernice houseparty
# 49                Parlando Italiano My Italian Lessons
# Name: name, dtype: object

# %%
venues_df = pd.DataFrame(venues)

venues_df.columns = ['Neighborhood', 'Latitude', 'Longitude', 'VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']
venues_df.to_csv('venues_df.csv', index = False)
print(venues_df.shape)
venues_df.head()
# Out:
# (50, 7)
#                                         Neighborhood  Latitude  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...     False
# 1  [{'id': '4bf58dd8d48988d114951735', 'name': 'B...     False
# 2  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...     False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...     False
# 4  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...     False
#
#                   Longitude  \
# 0  4c54126830f92d7f9f71d2b9
# 1  4ac518edf964a520c0ac20e3
# 2  4e805fb2dab41c952c505ffc
# 3  535e72ce498e70b6d38ba610
# 4  4eb026469a521bacdb927d65
#
#                                            VenueName  \
# 0  {'address': '121 - 125 Park St', 'lat': 51.513...
# 1  {'address': '5 Cecil Court', 'lat': 51.5107783...
# 2  {'address': '50a Berkeley St', 'lat': 51.50776...
# 3  {'address': '60c Holborn Viaduct', 'lat': 51.5...
# 4  {'address': '9 Sloane St', 'lat': 51.506452062...
#
#                  VenueLatitude VenueLongitude        VenueCategory
# 0                  ASK Italian   v-1575924515                  NaN
# 1             Italian Bookshop   v-1575924515                  NaN
# 2                      Novikov   v-1575924515  {'id': '121043084'}
# 3    Beboz Italian Street Food   v-1575924515  {'id': '132860391'}
# 4  Billionaire Italian Couture   v-1575924515                  NaN

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
    ).add_to(venues_map)

venues_map
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-148-507a424e5df0> in <module>
#       2
#       3 for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
# ----> 4     folium.features.CircleMarker(
#       5         [lat, lng],
#       6         radius=5,
#
# AttributeError: module 'folium.features' has no attribute 'CircleMarker'

# %% [markdown]
# If my code wasn't coming up with errors, i would use the k-means clustering model.
#
#
# If you have any suggestions to fix this please tell me
